# %% [markdown]
# ## Partie 1

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression
from scipy.optimize import approx_fprime
# %matplotlib notebook

# %%
X,y=make_regression(n_samples=100,n_features=1,n_informative=1,noise=20,random_state=42)
plt.scatter(X,y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Calculates MSE Given X, Y_true and theta
def MSE(data):
    X,Y_true,theta=data
    Y_pred=np.dot(X,theta)
    return np.sum((Y_true-Y_pred)**2)/X.shape[0]

# %%
#returns the gradient 
def Grad_function(X,Y_true,theta_loc):
    return approx_fprime([X,Y_true,theta_loc],MSE,epsilon=0.0001)[2]

# %%
def StandardGradientDecent(X,Y_true,theta_loc,T,learning_rate):
    mse=[]
    thetas=[]
    for i in range(T):
        theta_loc=theta_loc-learning_rate*Grad_function(X,Y_true,theta_loc)
        mse.append(MSE([X,Y_true,theta_loc]))
        thetas.append(theta_loc)
    plt.plot(mse)
    print(MSE([X,Y_true,theta_loc]))
    return theta_loc,thetas

# %%
def StochasticGradientDecent(X,Y_true,theta_loc,T,learning_rate):
    mse=[]
    thetas=[]
    for i in range(T):
        for (x,y) in zip(X,Y_true): 
            theta_loc=theta_loc-learning_rate*Grad_function(x,y,theta_loc)
            mse.append(MSE([X,Y_true,theta_loc]))
            thetas.append(theta_loc)
    plt.plot(mse)
    print(MSE([X,Y_true,theta_loc]))
    return theta_loc,thetas

# %%
#Slower to converge
tetaFinal,thetasBatch=StandardGradientDecent(X,y,np.array([0]),25,0.1)
# Out:
# 317.7906444013863

# %%
#Much faster to converge needs only one iteration
tetaFinal,thetasStochastic=StochasticGradientDecent(X,y,np.array([0]),1,0.1)
# Out:
# 343.71200989458305

# %%
#Plotting Standard Batch Gradient Decent
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.animation import FuncAnimation
plt.style.use('seaborn-pastel')


fig = plt.figure()
ax = plt.axes(xlim=(-3,3), ylim=(-100, 100))
line, = ax.plot([], [], lw=3)

def init():
    line.set_data([], [])
    return line,
def animate(i):
    line.set_data(X, np.dot(X,thetasBatch[i]))
    
    return line,
plt.scatter(X,y, marker='o',alpha=0.5)

anim = FuncAnimation(fig, animate, init_func=init,
                               frames=30, interval=500, blit=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Plotting Stocastic Gradient Decent
# %matplotlib notebook
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.animation import FuncAnimation
plt.style.use('seaborn-pastel')


fig = plt.figure()
ax = plt.axes(xlim=(-3,3), ylim=(-100, 100))
line, = ax.plot([], [], lw=3)

def init():
    line.set_data([], [])
    return line,
def animate(i):
    line.set_data(X, np.dot(X,thetasStochastic[i]))
    
    return line,
plt.scatter(X,y, marker='o',alpha=0.5)

anim = FuncAnimation(fig, animate, init_func=init,
                               frames=30, interval=500, blit=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Out:
# 1340.5973501610124

# %%
#Plotting Stocastic Gradient Decent
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.animation import FuncAnimation
plt.style.use('seaborn-pastel')


fig = plt.figure()
ax = plt.axes(xlim=(-50,100), ylim=(0, 8000))
point, = ax.plot(0,1, marker="o")

def init():
    point.set_data([], [])
    return line,
def animate(i):

    point.set_data(thetasStochastic[i], MSE([X,y,thetasStochastic[i]]))
    
    return point,

tetas=np.linspace(start=-50,stop=100,num=500)
mseResult=[MSE([X,y,np.array([teta])]) for teta in tetas]
plt.plot(tetas,mseResult)

anim = FuncAnimation(fig, animate, init_func=init,
                               frames=30, interval=500, blit=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Plotting Stocastic Gradient Decent
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.animation import FuncAnimation
plt.style.use('seaborn-pastel')


fig = plt.figure()
ax = plt.axes(xlim=(-50,100), ylim=(0, 8000))
point, = ax.plot(0,1, marker="o")

def init():
    point.set_data([], [])
    return line,
def animate(i):

    point.set_data(thetasBatch[i], MSE([X,y,thetasBatch[i]]))
    
    return point,

tetas=np.linspace(start=-50,stop=100,num=500)
mseResult=[MSE([X,y,np.array([teta])]) for teta in tetas]
plt.plot(tetas,mseResult)

anim = FuncAnimation(fig, animate, init_func=init,
                               frames=30, interval=500, blit=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def myFunc(x):
    return x**2-x**3+3

# %%
X=np.linspace(start=-20,stop=20,num=100)

plt.plot(X,myFunc(X))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def gradContiousFunc(X):
    n=X.shape[0]
    totalGradient=0
    for i in range(n):
        totalGradient+=approx_fprime(np.array([X[i]]),myFunc,epsilon=0.0001)
    return totalGradient/n

# %%
#myFunc(X)
gradContiousFunc(X)
# Out:
# array([-382.02310203])

# %%
"""
A simple example of an animated plot... In 3D!
"""
import numpy as np
import matplotlib.pyplot as plt
import mpl_toolkits.mplot3d.axes3d as p3
import matplotlib.animation as animation

def Gen_RandLine(length, dims=2) :
    """
    Create a line using a random walk algorithm

    length is the number of points for the line.
    dims is the number of dimensions the line has.
    """
    lineData = np.empty((dims, length))
    lineData[:, 0] = np.random.rand(dims)
    for index in range(1, length) :
        # scaling the random numbers by 0.1 so
        # movement is small compared to position.
        # subtraction by 0.5 is to change the range to [-0.5, 0.5]
        # to allow a line to move backwards.
        step = ((np.random.rand(dims) - 0.5) * 0.1)
        lineData[:, index] = lineData[:, index-1] + step

    return lineData

def update_lines(num, dataLines, lines) :
    for line, data in zip(lines, dataLines) :
        # NOTE: there is no .set_data() for 3 dim data...
        line.set_data(data[0:2, :num])
        line.set_3d_properties(data[2,:num])
    return lines

# Attaching 3D axis to the figure
fig = plt.figure()
ax = p3.Axes3D(fig)

# Fifty lines of random 3-D lines
data = [Gen_RandLine(25, 3) for index in range(50)]

# Creating fifty line objects.
# NOTE: Can't pass empty arrays into 3d version of plot()
lines = [ax.plot(dat[0, 0:1], dat[1, 0:1], dat[2, 0:1])[0] for dat in data]

# Setting the axes properties
ax.set_xlim3d([0.0, 1.0])
ax.set_xlabel('X')

ax.set_ylim3d([0.0, 1.0])
ax.set_ylabel('Y')

ax.set_zlim3d([0.0, 1.0])
ax.set_zlabel('Z')

ax.set_title('3D Test')

# Creating the Animation object
line_ani = animation.FuncAnimation(fig, update_lines, 25, fargs=(data, lines),
                              interval=50, blit=False)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# def bananaFunc(x,y):
#     return (1-x**2)+100*(y-x**2)**2

def bananaFunc(x,y):
    return (x+2*y-7)**2 + (2*x+y-5)**2

# %%
x=np.linspace(start=-10,stop=10)
y=np.linspace(start=-10,stop=10)
X, Y = np.meshgrid(x, y)
Z=bananaFunc(X,Y)

# %%
fig = plt.figure()
ax = p3.Axes3D(fig)
ax.set_xlim3d([-10, 10])
ax.set_xlabel('X')

ax.set_ylim3d([-10, 10])
ax.set_ylabel('Y')

ax.set_zlim3d([0, 2000])
ax.set_zlabel('Z')
ax.contour3D(X, Y, Z, 500)

ax.set_title('3D Test')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 0.92, '3D Test')
